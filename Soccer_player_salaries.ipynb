# %% [markdown]
# <a href="https://colab.research.google.com/github/artemisIsNotBeam/3d-printer-website/blob/main/Soccer_player_salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import

# i need to import regression and train test split

# %%
data = pd.read_csv("drive/MyDrive/raw_wages.csv")
#data['Salary'] = data['Salary'].str[2:-5]
data['Salary'] = data['Salary'].str.replace(',', '')
data['Salary'] = data['Salary'].str.replace('p/a','')
data['Salary'] = data['Salary'].str.replace('€','').astype(float)

justPrem = data[data['Division'].str.contains('Premier')]

justPrem.head(10)
# Out:
#                                 Name  \
# 15   - -
# 20   - -
# 21   - -
# 24   - -
# 25   - -
# 30   - -
# 31   - -
# 32   - -
# 40   - -
# 41   - -
#
#                                          Club  \
# 15   -
# 20   -
# 21   -
# 24   -
# 25   -
# 30   -
# 31   -
# 32   -
# 40   -
# 41   -
#
#                                              Division  \
# 15   Premier League                               ...
# 20   Premier League                               ...
# 21   Premier League                               ...
# 24   Premier League                               ...
# 25   Premier League                               ...
# 30   Premier League                               ...
# 31   Premier League                               ...
# 32   Premier League                               ...
# 40   Premier League                               ...
# 41   Premier League                               ...
#
#                                                 Based    Nat    EU National  \
# 15   England (Premier League)                     ...   BRA    Yes
# 20   England (Premier League)                     ...   ENG    No
# 21   England (Premier League)                     ...   EGY    No
# 24   England (Premier League)                     ...   NOR    Yes
# 25   England (Premier League)                     ...   BEL    Yes
# 30   England (Premier League)                     ...   FRA    Yes
# 31   England (Premier League)                     ...   BRA    Yes
# 32   England (Premier League)                     ...   ENG    No
# 40   England (Premier League)                     ...   ENG    No
# 41   England (Premier League)                     ...   ENG    Yes
#
#     Caps    AT Apps            Position   Age        CR        Begins  \
# 15  21.0   327                           30.0   8,864     15/8/2023
# 20  82.0   352                           28.0   8,158     13/7/2022
# 21  89.0   401                           31.0   9,325     1/7/2022
# 24  25.0   190                           23.0   9,406     1/7/2022
# 25  99.0   427                           32.0   9,503     5/7/2021
# 30  10.0   174                           25.0   8,100     1/7/2023
# 31  71.0   357                           31.0   7,892     22/8/2022
# 32  53.0   241                           25.0   8,003     18/7/2023
# 40  23.0   163                           23.0   7,200     23/7/2021
# 41  32.0   280                           27.0   8,289     5/8/2021
#
#          Expires                              Last Club    Last Trans. Fee  \
# 15   30/6/2028     Benfica                                €41M
# 20   30/6/2027     Man City                               €55M
# 21   30/6/2025     Roma                                   €40M
# 24   30/6/2027     Dortmund                               €59M
# 25   30/6/2025     Wolfsburg                              €63M
# 30   30/6/2029     RB Leipzig                             €60M
# 31   30/6/2026     Real Madrid                            €70M
# 32   30/6/2028                                            -
# 40   30/6/2026     Dortmund                               €85M
# 41   30/6/2027     Aston Villa                            €117M
#
#         Salary
# 15  22733000.0
# 20  21225000.0
# 21  21225000.0
# 24  20619000.0
# 25  20619000.0
# 30  18193000.0
# 31  18193000.0
# 32  18193000.0
# 40  16677000.0
# 41  16374000.0

# %%
y = justPrem['Salary']
x = justPrem[['EU National', 'Caps','AT Apps','CR','Age','Last Trans. Fee']]

x_train,y_train,x_test,y_test = train_test_split(x,y,.2)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-28d4d21f64c7> in <cell line: 1>()
# ----> 1 model = LinearRegression()
#
# NameError: name 'LinearRegression' is not defined
